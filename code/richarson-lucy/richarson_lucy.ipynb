# %% [markdown]
# # Finding the optimal iteration of Richardson-Lucy deconvolution
#
# Use this Google Colab notebook to implement or run your Richardson-Lucy deconvolution.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Add your code here
